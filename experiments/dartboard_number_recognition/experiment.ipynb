# %%
# !pip install ultralytics wandb

# %%
import ultralytics

ultralytics.checks()

# %%
# !yolo settings wandb=True

# %%
# !yolo detect train data=dataset_config.yaml model=yolo11n.pt project=dartboard_number_recognition name=n_pretrain pretrained=True epochs=50 batch=16 device=0

# %%
# !yolo detect train data=dataset_config.yaml model=yolo11n.pt project=dartboard_number_recognition name=n_scratch pretrained=False epochs=50 batch=16 device=0

# %%
# !yolo detect predict model=dartboard_number_recognition/n_scratch/weights/best.pt source=predict_images device=0
